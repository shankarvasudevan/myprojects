# %%
import wbdata
import pandas as pd
import datetime

#wbdata.get_indicator(source=59)

indicators = {"NW.NFA.TO":"Net foreign assets"}
dates = (datetime.datetime(1995, 1, 1), datetime.datetime(2017, 1, 1))

df  = wbdata.get_dataframe(indicators, data_date=dates)

df
# Out:
#                                                     Net foreign assets
# country                                       date
# East Asia & Pacific                           2014        3.827741e+12
#                                               2010        3.381944e+12
#                                               2005        1.428162e+12
#                                               2000        1.943177e+11
#                                               1995       -5.061383e+11
# East Asia & Pacific (low and middle income)   2014        7.843531e+11
#                                               2010        1.298463e+12
#                                               2005        2.389224e+11
#                                               2000       -5.404881e+11
#                                               1995       -7.132492e+11
# Europe & Central Asia                         2014       -1.357702e+12
# ...
